# %%
import pandas as pd
import shapely
import geopandas as gpd

# %%
pd.set_option('display.max_rows', 6)
pd.set_option('display.float_format', '{:.3f}'.format)

# %%
gdf = gpd.read_file('data/world.gpkg')

# %%
type(gdf)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
gdf.shape
# Out:
# (177, 11)

# %%
gdf
# Out:
#     iso_a2            name_long      continent region_un        subregion  \
# 0       FJ                 Fiji        Oceania   Oceania        Melanesia
# 1       TZ             Tanzania         Africa    Africa   Eastern Africa
# 2       EH       Western Sahara         Africa    Africa  Northern Africa
# ..     ...                  ...            ...       ...              ...
# 174     XK               Kosovo         Europe    Europe  Southern Europe
# 175     TT  Trinidad and Tobago  North America  Americas        Caribbean
# 176     SS          South Sudan         Africa    Africa   Eastern Africa
#
#                   type   area_km2          pop  lifeExp  gdpPercap  \
# 0    Sovereign country  19289.971   885806.000   69.960   8222.254
# 1    Sovereign country 932745.792 52234869.000   64.163   2402.099
# 2        Indeterminate  96270.601          NaN      NaN        NaN
# ..                 ...        ...          ...      ...        ...
# 174  Sovereign country  11230.262  1821800.000   71.098   8698.292
# 175  Sovereign country   7737.810  1354493.000   70.426  31181.821
# 176  Sovereign country 624909.099 11530971.000   55.817   1935.879
#
#                                               geometry
# 0    MULTIPOLYGON (((-180 -16.55522, -179.91737 -16...
# 1    MULTIPOLYGON (((33.90371 -0.95, 31.86617 -1.02...
# 2    MULTIPOLYGON (((-8.66559 27.65643, -8.81783 27...
# ..                                                 ...
# 174  MULTIPOLYGON (((20.59025 41.85541, 20.71731 41...
# 175  MULTIPOLYGON (((-61.68 10.76, -61.66 10.365, -...
# 176  MULTIPOLYGON (((30.83385 3.50917, 31.24556 3.7...
#
# [177 rows x 11 columns]

# %%
gdf[gdf['name_long'] == 'Egypt']
# Out:
#     iso_a2 name_long continent region_un        subregion               type  \
# 163     EG     Egypt    Africa    Africa  Northern Africa  Sovereign country
#
#       area_km2          pop  lifeExp  gdpPercap  \
# 163 996311.623 91812566.000   71.120   9879.799
#
#                                               geometry
# 163  MULTIPOLYGON (((36.86623 22, 36.69069 22.20485...

# %%
gdf.plot();

# %%
gdf.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1e6d4dec42e4133ea3112eb7878c073a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1e6d4dec42e4133ea3112eb7878c073a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1e6d4dec42e4133ea3112eb7878c073a = L.map(
#                 &quot;map_1e6d4dec42e4133ea3112eb7878c073a&quot;,
#                 {
#                     center: [-3.1274349999999984, -5.000000001587068e-06],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_1e6d4dec42e4133ea3112eb7878c073a);
#
#
#
#
#
#             var tile_layer_8623dca6a1900f0827edb25e7fb9ae6b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8623dca6a1900f0827edb25e7fb9ae6b.addTo(map_1e6d4dec42e4133ea3112eb7878c073a);
#
#
#             map_1e6d4dec42e4133ea3112eb7878c073a.fitBounds(
#                 [[-89.9, -180.0], [83.64513000000001, 179.99999]],
#                 {}
#             );
#
#
#         function geo_json_c4f16ace0662ac8a488f2305e2017393_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_c4f16ace0662ac8a488f2305e2017393_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_c4f16ace0662ac8a488f2305e2017393_pointToLayer(feature, latlng) {
#             var opts = {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;weight&quot;: 3,
#   &quot;opacity&quot;: 1.0,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3388ff&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;radius&quot;: 2,
# };
#
#             let style = geo_json_c4f16ace0662ac8a488f2305e2017393_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_c4f16ace0662ac8a488f2305e2017393_onEachFeature(feature, layer) {
#
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_c4f16ace0662ac8a488f2305e2017393.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_c4f16ace0662ac8a488f2305e2017393_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_c4f16ace0662ac8a488f2305e2017393 = L.geoJson(null, {
#                 onEachFeature: geo_json_c4f16ace0662ac8a488f2305e2017393_onEachFeature,
#
#                 style: geo_json_c4f16ace0662ac8a488f2305e2017393_styler,
#                 pointToLayer: geo_json_c4f16ace0662ac8a488f2305e2017393_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_c4f16ace0662ac8a488f2305e2017393_add (data) {
#             geo_json_c4f16ace0662ac8a488f2305e2017393
#                 .addData(data);
#         }
#             geo_json_c4f16ace0662ac8a488f2305e2017393_add({&quot;bbox&quot;: [-180.0, -89.9, 179.99999, 83.64513000000001], &quot;features&quot;: [{&quot;bbox&quot;: [-180.0, -18.287990000000004, 179.99999, -16.02088225674122], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[[-180.0, -16.555216566639196], [-179.9173693847653, -16.501783135649397], [-179.79332010904864, -16.02088225674122], [-180.0, -16.06713266364245], [-180.0, -16.555216566639196]]], [[[178.12557, -17.50481], [177.67087, -17.381140000000002], [177.

# %%
gdf[gdf['name_long'] == 'Egypt'].explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_58bf0e499fd03791b6672f7ed44786c3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_58bf0e499fd03791b6672f7ed44786c3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_58bf0e499fd03791b6672f7ed44786c3 = L.map(
#                 &quot;map_58bf0e499fd03791b6672f7ed44786c3&quot;,
#                 {
#                     center: [26.79284, 30.783149999999985],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_58bf0e499fd03791b6672f7ed44786c3);
#
#
#
#
#
#             var tile_layer_58b5d1100a9dac3144de6ffb06958a93 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_58b5d1100a9dac3144de6ffb06958a93.addTo(map_58bf0e499fd03791b6672f7ed44786c3);
#
#
#             map_58bf0e499fd03791b6672f7ed44786c3.fitBounds(
#                 [[22.0, 24.70007], [31.585680000000004, 36.86622999999997]],
#                 {}
#             );
#
#
#         function geo_json_178c98fa954b6bd59ee9e4c88fdad0b3_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_178c98fa954b6bd59ee9e4c88fdad0b3_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_178c98fa954b6bd59ee9e4c88fdad0b3_pointToLayer(feature, latlng) {
#             var opts = {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;weight&quot;: 3,
#   &quot;opacity&quot;: 1.0,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3388ff&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;radius&quot;: 2,
# };
#
#             let style = geo_json_178c98fa954b6bd59ee9e4c88fdad0b3_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_178c98fa954b6bd59ee9e4c88fdad0b3_onEachFeature(feature, layer) {
#
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_178c98fa954b6bd59ee9e4c88fdad0b3.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_178c98fa954b6bd59ee9e4c88fdad0b3_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_178c98fa954b6bd59ee9e4c88fdad0b3 = L.geoJson(null, {
#                 onEachFeature: geo_json_178c98fa954b6bd59ee9e4c88fdad0b3_onEachFeature,
#
#                 style: geo_json_178c98fa954b6bd59ee9e4c88fdad0b3_styler,
#                 pointToLayer: geo_json_178c98fa954b6bd59ee9e4c88fdad0b3_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_178c98fa954b6bd59ee9e4c88fdad0b3_add (data) {
#             geo_json_178c98fa954b6bd59ee9e4c88fdad0b3
#                 .addData(data);
#         }
#             geo_json_178c98fa954b6bd59ee9e4c88fdad0b3_add({&quot;bbox&quot;: [24.70007, 22.0, 36.86622999999997, 31.585680000000004], &quot;features&quot;: [{&quot;bbox&quot;: [24.70007, 22.0, 36.86622999999997, 31.585680000000004], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[[36.86622999999997, 22.0], [36.69069000000001, 22.204849999999997], [35.52598, 23.102440000000005], [35.49372, 23.752370000000003], [35.69241, 23.926709999999996], [34.79507, 25.033749999999998], [34.47387000000001, 25.598560000000006], [34.1045

# %%
gdf.geometry
# Out:
# 0      MULTIPOLYGON (((-180 -16.55522, -179.91737 -16...
# 1      MULTIPOLYGON (((33.90371 -0.95, 31.86617 -1.02...
# 2      MULTIPOLYGON (((-8.66559 27.65643, -8.81783 27...
#                              ...
# 174    MULTIPOLYGON (((20.59025 41.85541, 20.71731 41...
# 175    MULTIPOLYGON (((-61.68 10.76, -61.66 10.365, -...
# 176    MULTIPOLYGON (((30.83385 3.50917, 31.24556 3.7...
# Name: geometry, Length: 177, dtype: geometry

# %%
gdf.geometry.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
gdf.envelope
# Out:
# 0      POLYGON ((-180 -18.28799, 179.99999 -18.28799,...
# 1      POLYGON ((29.34 -11.72094, 40.31659 -11.72094,...
# 2      POLYGON ((-17.06342 20.99975, -8.66512 20.9997...
#                              ...
# 174    POLYGON ((20.0707 41.84711, 21.77505 41.84711,...
# 175    POLYGON ((-61.95 10, -60.895 10, -60.895 10.89...
# 176    POLYGON ((23.88698 3.50917, 35.29801 3.50917, ...
# Length: 177, dtype: geometry

# %%
gdf.envelope[0].wkt
# Out:
# 'POLYGON ((-180 -18.287990000000004, 179.99999 -18.287990000000004, 179.99999 -16.02088225674122, -180 -16.02088225674122, -180 -18.287990000000004))'

# %%
gdf2 = gdf.copy()
gdf2.geometry = gdf.envelope
gdf2
# Out:
#     iso_a2            name_long      continent region_un        subregion  \
# 0       FJ                 Fiji        Oceania   Oceania        Melanesia
# 1       TZ             Tanzania         Africa    Africa   Eastern Africa
# 2       EH       Western Sahara         Africa    Africa  Northern Africa
# ..     ...                  ...            ...       ...              ...
# 174     XK               Kosovo         Europe    Europe  Southern Europe
# 175     TT  Trinidad and Tobago  North America  Americas        Caribbean
# 176     SS          South Sudan         Africa    Africa   Eastern Africa
#
#                   type   area_km2          pop  lifeExp  gdpPercap  \
# 0    Sovereign country  19289.971   885806.000   69.960   8222.254
# 1    Sovereign country 932745.792 52234869.000   64.163   2402.099
# 2        Indeterminate  96270.601          NaN      NaN        NaN
# ..                 ...        ...          ...      ...        ...
# 174  Sovereign country  11230.262  1821800.000   71.098   8698.292
# 175  Sovereign country   7737.810  1354493.000   70.426  31181.821
# 176  Sovereign country 624909.099 11530971.000   55.817   1935.879
#
#                                               geometry
# 0    POLYGON ((-180 -18.28799, 179.99999 -18.28799,...
# 1    POLYGON ((29.34 -11.72094, 40.31659 -11.72094,...
# 2    POLYGON ((-17.06342 20.99975, -8.66512 20.9997...
# ..                                                 ...
# 174  POLYGON ((20.0707 41.84711, 21.77505 41.84711,...
# 175  POLYGON ((-61.95 10, -60.895 10, -60.895 10.89...
# 176  POLYGON ((23.88698 3.50917, 35.29801 3.50917, ...
#
# [177 rows x 11 columns]

# %%
gdf.geometry.type
# Out:
# 0      MultiPolygon
# 1      MultiPolygon
# 2      MultiPolygon
#            ...
# 174    MultiPolygon
# 175    MultiPolygon
# 176    MultiPolygon
# Length: 177, dtype: object

# %%
gdf.geometry.type.value_counts()
# Out:
# MultiPolygon    177
# Name: count, dtype: int64

# %%
gdf['bbox'] = gdf.envelope
gdf['polygon'] = gdf.geometry
gdf
# Out:
#     iso_a2            name_long      continent region_un        subregion  \
# 0       FJ                 Fiji        Oceania   Oceania        Melanesia
# 1       TZ             Tanzania         Africa    Africa   Eastern Africa
# 2       EH       Western Sahara         Africa    Africa  Northern Africa
# ..     ...                  ...            ...       ...              ...
# 174     XK               Kosovo         Europe    Europe  Southern Europe
# 175     TT  Trinidad and Tobago  North America  Americas        Caribbean
# 176     SS          South Sudan         Africa    Africa   Eastern Africa
#
#                   type   area_km2          pop  lifeExp  gdpPercap  \
# 0    Sovereign country  19289.971   885806.000   69.960   8222.254
# 1    Sovereign country 932745.792 52234869.000   64.163   2402.099
# 2        Indeterminate  96270.601          NaN      NaN        NaN
# ..                 ...        ...          ...      ...        ...
# 174  Sovereign country  11230.262  1821800.000   71.098   8698.292
# 175  Sovereign country   7737.810  1354493.000   70.426  31181.821
# 176  Sovereign country 624909.099 11530971.000   55.817   1935.879
#
#                                               geometry  \
# 0    MULTIPOLYGON (((-180 -16.55522, -179.91737 -16...
# 1    MULTIPOLYGON (((33.90371 -0.95, 31.86617 -1.02...
# 2    MULTIPOLYGON (((-8.66559 27.65643, -8.81783 27...
# ..                                                 ...
# 174  MULTIPOLYGON (((20.59025 41.85541, 20.71731 41...
# 175  MULTIPOLYGON (((-61.68 10.76, -61.66 10.365, -...
# 176  MULTIPOLYGON (((30.83385 3.50917, 31.24556 3.7...
#
#                                                   bbox  \
# 0    POLYGON ((-180 -18.28799, 179.99999 -18.28799,...
# 1    POLYGON ((29.34 -11.72094, 40.31659 -11.72094,...
# 2    POLYGON ((-17.06342 20.99975, -8.66512 20.9997...
# ..                                                 ...
# 174  POLYGON ((20.0707 41.84711, 21.77505 41.84711,...
# 175  POLYGON ((-61.95 10, -60.895 10, -60.895 10.89...
# 176  POLYGON ((23.88698 3.50917, 35.29801 3.50917, ...
#
#                                                polygon
# 0    MULTIPOLYGON (((-180 -16.55522, -179.91737 -16...
# 1    MULTIPOLYGON (((33.90371 -0.95, 31.86617 -1.02...
# 2    MULTIPOLYGON (((-8.66559 27.65643, -8.81783 27...
# ..                                                 ...
# 174  MULTIPOLYGON (((20.59025 41.85541, 20.71731 41...
# 175  MULTIPOLYGON (((-61.68 10.76, -61.66 10.365, -...
# 176  MULTIPOLYGON (((30.83385 3.50917, 31.24556 3.7...
#
# [177 rows x 13 columns]

# %%
gdf = gdf.set_geometry('bbox')
gdf.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b6f33ab658ab7475d7bac29830d5995d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b6f33ab658ab7475d7bac29830d5995d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b6f33ab658ab7475d7bac29830d5995d = L.map(
#                 &quot;map_b6f33ab658ab7475d7bac29830d5995d&quot;,
#                 {
#                     center: [-3.1274349999999984, -5.000000001587068e-06],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_b6f33ab658ab7475d7bac29830d5995d);
#
#
#
#
#
#             var tile_layer_a29932f36bcd54ad3f1f27fd1e8cdf1c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a29932f36bcd54ad3f1f27fd1e8cdf1c.addTo(map_b6f33ab658ab7475d7bac29830d5995d);
#
#
#             map_b6f33ab658ab7475d7bac29830d5995d.fitBounds(
#                 [[-89.9, -180.0], [83.64513000000001, 179.99999]],
#                 {}
#             );
#
#
#         function geo_json_5299361ff7675efdad208228d4dd16ef_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_5299361ff7675efdad208228d4dd16ef_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_5299361ff7675efdad208228d4dd16ef_pointToLayer(feature, latlng) {
#             var opts = {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;weight&quot;: 3,
#   &quot;opacity&quot;: 1.0,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3388ff&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;radius&quot;: 2,
# };
#
#             let style = geo_json_5299361ff7675efdad208228d4dd16ef_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_5299361ff7675efdad208228d4dd16ef_onEachFeature(feature, layer) {
#
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_5299361ff7675efdad208228d4dd16ef.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_5299361ff7675efdad208228d4dd16ef_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_5299361ff7675efdad208228d4dd16ef = L.geoJson(null, {
#                 onEachFeature: geo_json_5299361ff7675efdad208228d4dd16ef_onEachFeature,
#
#                 style: geo_json_5299361ff7675efdad208228d4dd16ef_styler,
#                 pointToLayer: geo_json_5299361ff7675efdad208228d4dd16ef_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_5299361ff7675efdad208228d4dd16ef_add (data) {
#             geo_json_5299361ff7675efdad208228d4dd16ef
#                 .addData(data);
#         }
#             geo_json_5299361ff7675efdad208228d4dd16ef_add({&quot;bbox&quot;: [-180.0, -89.9, 179.99999, 83.64513000000001], &quot;features&quot;: [{&quot;bbox&quot;: [-180.0, -18.287990000000004, 179.99999, -16.02088225674122], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-180.0, -18.287990000000004], [179.99999, -18.287990000000004], [179.99999, -16.02088225674122], [-180.0, -16.02088225674122], [-180.0, -18.287990000000004]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properti

# %%
gdf = gdf.set_geometry('polygon')
gdf.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3735da8325e3927d22d3f93908d1aca7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3735da8325e3927d22d3f93908d1aca7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3735da8325e3927d22d3f93908d1aca7 = L.map(
#                 &quot;map_3735da8325e3927d22d3f93908d1aca7&quot;,
#                 {
#                     center: [-3.1274349999999984, -5.000000001587068e-06],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_3735da8325e3927d22d3f93908d1aca7);
#
#
#
#
#
#             var tile_layer_dd638bff9d2bfeec1a3e0425de1befb8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_dd638bff9d2bfeec1a3e0425de1befb8.addTo(map_3735da8325e3927d22d3f93908d1aca7);
#
#
#             map_3735da8325e3927d22d3f93908d1aca7.fitBounds(
#                 [[-89.9, -180.0], [83.64513000000001, 179.99999]],
#                 {}
#             );
#
#
#         function geo_json_0c53982160840feda13a749dde6ec804_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_0c53982160840feda13a749dde6ec804_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_0c53982160840feda13a749dde6ec804_pointToLayer(feature, latlng) {
#             var opts = {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;weight&quot;: 3,
#   &quot;opacity&quot;: 1.0,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3388ff&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;radius&quot;: 2,
# };
#
#             let style = geo_json_0c53982160840feda13a749dde6ec804_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_0c53982160840feda13a749dde6ec804_onEachFeature(feature, layer) {
#
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_0c53982160840feda13a749dde6ec804.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_0c53982160840feda13a749dde6ec804_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_0c53982160840feda13a749dde6ec804 = L.geoJson(null, {
#                 onEachFeature: geo_json_0c53982160840feda13a749dde6ec804_onEachFeature,
#
#                 style: geo_json_0c53982160840feda13a749dde6ec804_styler,
#                 pointToLayer: geo_json_0c53982160840feda13a749dde6ec804_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_0c53982160840feda13a749dde6ec804_add (data) {
#             geo_json_0c53982160840feda13a749dde6ec804
#                 .addData(data);
#         }
#             geo_json_0c53982160840feda13a749dde6ec804_add({&quot;bbox&quot;: [-180.0, -89.9, 179.99999, 83.64513000000001], &quot;features&quot;: [{&quot;bbox&quot;: [-180.0, -18.287990000000004, 179.99999, -16.02088225674122], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[[-180.0, -16.555216566639196], [-179.9173693847653, -16.501783135649397], [-179.79332010904864, -16.02088225674122], [-180.0, -16.06713266364245], [-180.0, -16.555216566639196]]], [[[178.12557, -17.50481], [177.67087, -17.381140000000002], [177.

# %%
gdf.geometry.iloc[5]
# Out:
# <MULTIPOLYGON (((87.36 49.215, 86.829 49.827, 85.541 49.693, 85.116 50.117, ...>

# %%
gdf[gdf['name_long'] == 'Egypt'].geometry.iloc[0]
# Out:
# <MULTIPOLYGON (((36.866 22, 36.691 22.205, 35.526 23.102, 35.494 23.752, 35....>

# %%
multipolygon = shapely.MultiPolygon([
    shapely.Polygon([(1,5), (2,2), (4,1), (4,4), (1,5)]),  ## Polygon 1 
    shapely.Polygon([(0,2), (1,2), (1,3), (0,3), (0,2)])   ## Polygon 2, etc.
])
multipolygon
# Out:
# <MULTIPOLYGON (((1 5, 2 2, 4 1, 4 4, 1 5)), ((0 2, 1 2, 1 3, 0 3, 0 2)))>

# %%
multipolygon.buffer(0.2).difference(multipolygon)
# Out:
# <MULTIPOLYGON (((4.063 4.19, 4.081 4.183, 4.098 4.174, 4.115 4.164, 4.13 4.1...>

# %%
lnd_point = shapely.Point(0.1, 51.5)
lnd_geom = gpd.GeoSeries([lnd_point], crs=4326)
lnd_geom
# Out:
# 0    POINT (0.1 51.5)
# dtype: geometry

# %%
lnd_data = {
    'name': ['London'],
    'temperature': [25],
    'date': ['2023-06-21'],
    'geometry': lnd_geom,
}

# %%
lnd_layer = gpd.GeoDataFrame(lnd_data)
lnd_layer
# Out:
#      name  temperature        date          geometry
# 0  London           25  2023-06-21  POINT (0.1 51.5)

# %%
lnd_point = shapely.Point(0.1, 51.5)
paris_point = shapely.Point(2.3, 48.9)
towns_geom = gpd.GeoSeries([lnd_point, paris_point], crs=4326)
towns_data = {
  'name': ['London', 'Paris'],
  'temperature': [25, 27],
  'date': ['2013-06-21', '2013-06-21'],
  'geometry': towns_geom
}
towns_layer = gpd.GeoDataFrame(towns_data)
towns_layer
# Out:
#      name  temperature        date          geometry
# 0  London           25  2013-06-21  POINT (0.1 51.5)
# 1   Paris           27  2013-06-21  POINT (2.3 48.9)

# %%
towns_layer.explore(color='red', marker_kwds={'radius':10})
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_08ddfc21c53db0558f69ac4788c697b1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_08ddfc21c53db0558f69ac4788c697b1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_08ddfc21c53db0558f69ac4788c697b1 = L.map(
#                 &quot;map_08ddfc21c53db0558f69ac4788c697b1&quot;,
#                 {
#                     center: [50.2, 1.2],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_08ddfc21c53db0558f69ac4788c697b1);
#
#
#
#
#
#             var tile_layer_86f48afb8dbe4700f8defa27511f4891 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_86f48afb8dbe4700f8defa27511f4891.addTo(map_08ddfc21c53db0558f69ac4788c697b1);
#
#
#             map_08ddfc21c53db0558f69ac4788c697b1.fitBounds(
#                 [[48.9, 0.1], [51.5, 2.3]],
#                 {}
#             );
#
#
#         function geo_json_1389dd6f66d97c092534f3e0946ceda0_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;red&quot;, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_1389dd6f66d97c092534f3e0946ceda0_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_1389dd6f66d97c092534f3e0946ceda0_pointToLayer(feature, latlng) {
#             var opts = {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;weight&quot;: 3,
#   &quot;opacity&quot;: 1.0,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3388ff&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;radius&quot;: 10,
# };
#
#             let style = geo_json_1389dd6f66d97c092534f3e0946ceda0_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_1389dd6f66d97c092534f3e0946ceda0_onEachFeature(feature, layer) {
#
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_1389dd6f66d97c092534f3e0946ceda0.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_1389dd6f66d97c092534f3e0946ceda0_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_1389dd6f66d97c092534f3e0946ceda0 = L.geoJson(null, {
#                 onEachFeature: geo_json_1389dd6f66d97c092534f3e0946ceda0_onEachFeature,
#
#                 style: geo_json_1389dd6f66d97c092534f3e0946ceda0_styler,
#                 pointToLayer: geo_json_1389dd6f66d97c092534f3e0946ceda0_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_1389dd6f66d97c092534f3e0946ceda0_add (data) {
#             geo_json_1389dd6f66d97c092534f3e0946ceda0
#                 .addData(data);
#         }
#             geo_json_1389dd6f66d97c092534f3e0946ceda0_add({&quot;bbox&quot;: [0.1, 48.9, 2.3, 51.5], &quot;features&quot;: [{&quot;bbox&quot;: [0.1, 51.5, 0.1, 51.5], &quot;geometry&quot;: {&quot;coordinates&quot;: [0.1, 51.5], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;__folium_color&quot;: &quot;red&quot;, &quot;date&quot;: &quot;2013-06-21&quot;, &quot;name&quot;: &quot;London&quot;, &quot;temperature&quot;: 25}, &quot;type&quot;: &quot;Fea

# %%
import xyzservices as xyz

# %%
[p for p in dir(xyz.providers) if not p.startswith('_')]
# Out:
# ['AzureMaps',
#  'BaseMapDE',
#  'BasemapAT',
#  'CartoDB',
#  'CyclOSM',
#  'Esri',
#  'FreeMapSK',
#  'Gaode',
#  'GeoportailFrance',
#  'HERE',
#  'HEREv3',
#  'HikeBike',
#  'Jawg',
#  'JusticeMap',
#  'MapBox',
#  'MapTiler',
#  'MapTilesAPI',
#  'MtbMap',
#  'NASAGIBS',
#  'NLS',
#  'OPNVKarte',
#  'OneMapSG',
#  'OpenAIP',
#  'OpenFireMap',
#  'OpenRailwayMap',
#  'OpenSeaMap',
#  'OpenSnowMap',
#  'OpenStreetMap',
#  'OpenTopoMap',
#  'OpenWeatherMap',
#  'OrdnanceSurvey',
#  'SafeCast',
#  'Stadia',
#  'Strava',
#  'SwissFederalGeoportal',
#  'Thunderforest',
#  'TomTom',
#  'TopPlusOpen',
#  'UN',
#  'USGS',
#  'WaymarkedTrails',
#  'nlmaps']

# %%
[p for p in dir(xyz.providers.Esri) if not p.startswith('_')]
# Out:
# ['AntarcticBasemap',
#  'AntarcticImagery',
#  'ArcticImagery',
#  'ArcticOceanBase',
#  'ArcticOceanReference',
#  'NatGeoWorldMap',
#  'OceanBasemap',
#  'WorldGrayCanvas',
#  'WorldImagery',
#  'WorldPhysical',
#  'WorldShadedRelief',
#  'WorldStreetMap',
#  'WorldTerrain',
#  'WorldTopoMap']

# %%
import xyzservices.providers as xyz
towns_layer.explore(color='red', marker_kwds={'radius':10},
                    tiles=xyz.Esri.WorldStreetMap)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7dca72439601e6b86eb74c2d8772dc3a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7dca72439601e6b86eb74c2d8772dc3a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7dca72439601e6b86eb74c2d8772dc3a = L.map(
#                 &quot;map_7dca72439601e6b86eb74c2d8772dc3a&quot;,
#                 {
#                     center: [50.2, 1.2],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_7dca72439601e6b86eb74c2d8772dc3a);
#
#
#
#
#
#             var tile_layer_d5d7edd29b9a7d7be5510d8091036dfe = L.tileLayer(
#                 &quot;https://server.arcgisonline.com/ArcGIS/rest/services/World_Street_Map/MapServer/tile/{z}/{y}/{x}&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Tiles \u0026copy; Esri \u0026mdash; Source: Esri, DeLorme, NAVTEQ, USGS, Intermap, iPC, NRCAN, Esri Japan, METI, Esri China (Hong Kong), Esri (Thailand), TomTom, 2012&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d5d7edd29b9a7d7be5510d8091036dfe.addTo(map_7dca72439601e6b86eb74c2d8772dc3a);
#
#
#             map_7dca72439601e6b86eb74c2d8772dc3a.fitBounds(
#                 [[48.9, 0.1], [51.5, 2.3]],
#                 {}
#             );
#
#
#         function geo_json_fec9212318becc86c4585d9cd97c8689_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;red&quot;, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_fec9212318becc86c4585d9cd97c8689_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_fec9212318becc86c4585d9cd97c8689_pointToLayer(feature, latlng) {
#             var opts = {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;weight&quot;: 3,
#   &quot;opacity&quot;: 1.0,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3388ff&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;radius&quot;: 10,
# };
#
#             let style = geo_json_fec9212318becc86c4585d9cd97c8689_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_fec9212318becc86c4585d9cd97c8689_onEachFeature(feature, layer) {
#
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_fec9212318becc86c4585d9cd97c8689.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_fec9212318becc86c4585d9cd97c8689_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_fec9212318becc86c4585d9cd97c8689 = L.geoJson(null, {
#                 onEachFeature: geo_json_fec9212318becc86c4585d9cd97c8689_onEachFeature,
#
#                 style: geo_json_fec9212318becc86c4585d9cd97c8689_styler,
#                 pointToLayer: geo_json_fec9212318becc86c4585d9cd97c8689_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_fec9212318becc86c4585d9cd97c8689_add (data) {
#             geo_json_fec9212318becc86c4585d9cd97c8689
#                 .addData(data);
#         }
#             geo_json_fec9212318becc86c4585d9cd97c8689_add({&quot;bbox&quot;: [0.1, 48.9, 2.3, 51.5], &quot;features&quot;: [{&quot;bbox&quot;: [0.1, 51.5, 0.1, 51.5], &quot;geometry&quot;: {&quot;coordinates&quot;: [0.1, 51.5], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;__folium_color&quot;: &quot;red&quot;, &quot;date&quot;: &quot;2013-06-21&quot;, &qu

# %%
import xyzservices
[p for p in dir(xyz.Esri) if not p.startswith('_')]
# Out:
# ['AntarcticBasemap',
#  'AntarcticImagery',
#  'ArcticImagery',
#  'ArcticOceanBase',
#  'ArcticOceanReference',
#  'NatGeoWorldMap',
#  'OceanBasemap',
#  'WorldGrayCanvas',
#  'WorldImagery',
#  'WorldPhysical',
#  'WorldShadedRelief',
#  'WorldStreetMap',
#  'WorldTerrain',
#  'WorldTopoMap']

# %%
point = shapely.Point([5, 2])

linestring = shapely.LineString([(1,5), (4,4), (4,1), (2,2), (3,2)])

polygon = shapely.Polygon(
    [(1,5), (2,2), (4,1), (4,4), (1,5)],  ## Exterior
    [[(2,4), (3,4), (3,3), (2,3), (2,4)]]  ## Hole(s)
)

multipolygon = shapely.MultiPolygon([
    [[(1,5), (2,2), (4,1), (4,4), (1,5)], []],  ## Polygon 1 
    [[(0,2), (1,2), (1,3), (0,3), (0,2)], []]   ## Polygon 2, etc.
])

print(linestring.length)

print(multipolygon.area)
# Out:
# 9.39834563766817
# 8.0

# %%
gpd.GeoSeries([point, linestring, polygon, multipolygon]).area
# Out:
# 0   0.000
# 1   0.000
# 2   6.000
# 3   8.000
# dtype: float64

# %%
gdf[gdf['name_long'] == 'Slovenia'].to_crs(32633).area
# Out:
# 150   19104099960.603
# dtype: float64

# %% [markdown]
# ## Raster data

# %% [markdown]
# import numpy as np
# import rasterio
# import rasterio.plot

# %%
import numpy as np
import rasterio
import rasterio.plot

# %%
src = rasterio.open('data/srtm.tif')
src
# Out:
# <open DatasetReader name='data/srtm.tif' mode='r'>

# %%
rasterio.plot.show(src);

# %%
src.meta
# Out:
# {'driver': 'GTiff',
#  'dtype': 'uint16',
#  'nodata': 65535.0,
#  'width': 465,
#  'height': 457,
#  'count': 1,
#  'crs': CRS.from_wkt('GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS 84",6378137,298.257223563,AUTHORITY["EPSG","7030"]],AUTHORITY["EPSG","6326"]],PRIMEM["Greenwich",0,AUTHORITY["EPSG","8901"]],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AXIS["Latitude",NORTH],AXIS["Longitude",EAST],AUTHORITY["EPSG","4326"]]'),
#  'transform': Affine(0.0008333333332777796, 0.0, -113.23958321278403,
#         0.0, -0.0008333333332777843, 37.512916763165805)}

# %%
src.read(1)
# Out:
# array([[1728, 1718, 1715, ..., 2654, 2674, 2685],
#        [1737, 1727, 1717, ..., 2649, 2677, 2693],
#        [1739, 1734, 1727, ..., 2644, 2672, 2695],
#        ...,
#        [1326, 1328, 1329, ..., 1777, 1778, 1775],
#        [1320, 1323, 1326, ..., 1771, 1770, 1772],
#        [1319, 1319, 1322, ..., 1768, 1770, 1772]],
#       shape=(457, 465), dtype=uint16)

# %%
elev = np.arange(1,37,dtype=np.uint8).reshape(6,6)

v = [
  1, 0, 1, 2, 2, 2, 
  0, 2, 0, 0, 2, 1, 
  0, 2, 2, 0, 0, 2, 
  0, 0, 1, 1, 1, 1, 
  1, 1, 1, 2, 1, 1, 
  2, 1, 2, 2, 0, 2
]
grain = np.array(v, dtype=np.uint8).reshape(6, 6)

# %%
new_transform = rasterio.transform.from_origin(
    west=-1.5,
    north=1.5,
    xsize=0.5,
    ysize=0.5
)

new_transform
# Out:
# Affine(0.5, 0.0, -1.5,
#        0.0, -0.5, 1.5)

# %%
rasterio.plot.show(elev, transform=new_transform);

# %%
rasterio.plot.show(grain, transform=new_transform);

# %%
new_dataset = rasterio.open(
    'output/elev.tif', 'w', 
    driver='GTiff',
    height=elev.shape[0],
    width=elev.shape[1],
    count=1,
    dtype=elev.dtype,
    crs=4326,
    transform=new_transform
)
new_dataset.write(elev, 1)
new_dataset.close()

# %%
new_dataset = rasterio.open(
    'output/grain.tif', 'w', 
    driver='GTiff',
    height=grain.shape[0],
    width=grain.shape[1],
    count=1,
    dtype=grain.dtype,
    crs=4326,
    transform=new_transform
)
new_dataset.write(grain, 1)
new_dataset.close()

# %%
import pyproj

epsg_codes = pyproj.get_codes('EPSG', 'CRS')
epsg_codes[:5]
# Out:
# ['10150', '10151', '10156', '10157', '10158']

# %%
pyproj.CRS.from_epsg(4326)
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
zion = gpd.read_file('data/zion.gpkg')
zion.crs
# Out:
# <Bound CRS: PROJCS["UTM Zone 12, Northern Hemisphere",GEOGCS[" ...>
# Name: UTM Zone 12, Northern Hemisphere
# Axis Info [cartesian]:
# - [east]: Easting (Meter)
# - [north]: Northing (Meter)
# Area of Use:
# - undefined
# Coordinate Operation:
# - name: Transformation from GRS 1980(IUGG, 1980) to WGS84
# - method: Position Vector transformation (geog2D domain)
# Datum: unknown
# - Ellipsoid: GRS80
# - Prime Meridian: Greenwich
# Source CRS: UTM Zone 12, Northern Hemisphere

# %%
zion.to_crs(4326).plot(edgecolor='black', color='lightgray').grid()
zion.plot(edgecolor='black', color='lightgrey').grid()

# %%
src.meta
# Out:
# {'driver': 'GTiff',
#  'dtype': 'uint16',
#  'nodata': 65535.0,
#  'width': 465,
#  'height': 457,
#  'count': 1,
#  'crs': CRS.from_wkt('GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS 84",6378137,298.257223563,AUTHORITY["EPSG","7030"]],AUTHORITY["EPSG","6326"]],PRIMEM["Greenwich",0,AUTHORITY["EPSG","8901"]],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AXIS["Latitude",NORTH],AXIS["Longitude",EAST],AUTHORITY["EPSG","4326"]]'),
#  'transform': Affine(0.0008333333332777796, 0.0, -113.23958321278403,
#         0.0, -0.0008333333332777843, 37.512916763165805)}
